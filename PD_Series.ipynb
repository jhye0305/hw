# %% [markdown]
# <a href="https://colab.research.google.com/github/jhye0305/tasks/blob/main/PD_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.Series([1, 2, 3],
              index =["a","b","c"])
s2 = pd.Series([4, 5, 6],
              index =["d","e","f"])
ds = s + s2
ds
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# f   NaN
# dtype: float64

# %%
import pandas as pd
data = {
    "2018": [1, 2, 3, 4],
    "2019": [5, 6, 7, 8],
    "2020": [9, 10, 11, 12],
    "2021": [13, 14, 15, 16],
    "지역": ["수도권", "경상권", "수도권","경상권"]
}
index = ["서울","부산","인천","대구"]
columns = ["2018", "2019","2020","2021","지역"]
a = pd.DataFrame(data=data, index = index, columns = columns)
a
# Out:
#     2018  2019  2020  2021   지역
# 서울     1     5     9    13  수도권
# 부산     2     6    10    14  경상권
# 인천     3     7    11    15  수도권
# 대구     4     8    12    16  경상권

# %%
data = {
    "국어": [80, 90, 70, 30],
    "영어": [90, 70, 60, 40],
    "수학": [90, 60, 80, 70],
}
columns = ["국어", "영어", "수학"]
index = ["춘향", "몽룡", "향단", "방자"]
df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#     국어  영어  수학
# 춘향  80  90  90
# 몽룡  90  70  60
# 향단  70  60  80
# 방자  30  40  70

# %%
data = df["수학"]
type(data)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(data)
s
# Out:
# 춘향    90
# 몽룡    60
# 향단    80
# 방자    70
# Name: 수학, dtype: int64

# %%
data = df[["국어","영어"]]
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df["평균"]= df.mean(axis=1)
df
# Out:
#     국어  영어  수학         평균
# 춘향  80  90  90  86.666667
# 몽룡  90  70  60  73.333333
# 향단  70  60  80  70.000000
# 방자  30  40  70  46.666667

# %%
df["영어"]["방자"] = 80
df["평균"]= df.mean(axis=1)
df
# Out:
# <ipython-input-19-f25becbedf8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["영어"]["방자"] = 80
#     국어  영어  수학         평균
# 춘향  80  90  90  86.666667
# 몽룡  90  70  60  73.333333
# 향단  70  60  80  70.000000
# 방자  30  80  70  56.666667

# %%
df[:1]
# Out:
#     국어  영어  수학         평균
# 춘향  80  90  90  86.666667

# %%
df.T["향단"]
# Out:
# 국어    70.0
# 영어    60.0
# 수학    80.0
# 평균    70.0
# Name: 향단, dtype: float64
