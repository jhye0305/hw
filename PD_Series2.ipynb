# %% [markdown]
# <a href="https://colab.research.google.com/github/jhye0305/tasks/blob/main/PD_Series2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(1, 26).reshape(5, 5),
                  index=["a", "b", "c", "d", "e"],
                  columns=["A", "B", "C", "D", "E"])
df
# Out:
#     A   B   C   D   E
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df.loc["a", "A"]
# Out:
# 1

# %%
df.loc["d", "E"]
# Out:
# 20

# %%
df.loc["b":, "A"]
# Out:
# b     6
# c    11
# d    16
# e    21
# Name: A, dtype: int64

# %%
df.loc["b", :]
# Out:
# A     6
# B     7
# C     8
# D     9
# E    10
# Name: b, dtype: int64

# %%
df.loc[["b", "c"], ["B", "D"]]
# Out:
#     B   D
# b   7   9
# c  12  14

# %%
df.iloc[0, 1]
# Out:
# 2

# %%
df.iloc[0, -2:]
# Out:
# D    4
# E    5
# Name: a, dtype: int64

# %%
df.iloc[-3]
# Out:
# A    11
# B    12
# C    13
# D    14
# E    15
# Name: c, dtype: int64

# %%
df.iloc[-1] = df.iloc[-1] * 3
df
# Out:
#     A   B   C   D   E
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  63  66  69  72  75
